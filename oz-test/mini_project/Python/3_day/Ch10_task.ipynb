# %% [markdown]
# <span style="font-size:100%">
#
# 수업은 모두 열심히 들으셨나요?
#
# 간혹 강의에서 언급되지 않은 내용이 문제로 나올 수 있습니다.<br>
# 그럴땐 강의 내용 외 문제는 구글링을 통해 해결해주세요<br></span>
# <span style="font-size:80%">
# (구글링 또한 개발자가 갖쳐야할 역량 중에 하나랍니다 😊)
# </span>
#
# ---

# %% [markdown]
# <span style="font-size:80%">[문제1]<br><br></span>
# 아래 리스트에 들어있는 값의 평균을 구하는 코드를 작성해주세요
#
# x = [34, 22, 10, 3, 55, 66]

# %% [markdown]
# <span style="color:red">답변</span>

# %%
x = [34, 22, 10, 3, 55, 66]

# sum(x)로 리스트의 합을 구하고 lex(x)로 리스트의 길이를 구하고 둘의 값을 나누어 평균을 구함
average = sum(x) / len(x)

print("평균:", average)
# Out:
# 평균: 31.666666666666668

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제2]<br><br></span>
# 리스트 안에 있는 데이터를 오름차순으로 정렬하는 메소드를 모두 골라주세요
#
# 1. upper()
# 2. low()
# 3. sort()
# 4. hight()
# 5. sorted()

# %% [markdown]
# <span style="color:red">답변</span>

# %%
x = [34, 22, 10, 3, 55, 66]

# 1. sort() 메소드를 사용하여 리스트를 오름차순으로 정렬
x.sort()
print("sort() 메서드를 사용한 결과:", x)

# 2. sorted() 함수를 사용하여 리스트를 오름차순으로 정렬
sorted_x = sorted(x)
print("sorted() 함수를 사용한 결과:", sorted_x)
# Out:
# sort() 메서드를 사용한 결과: [3, 10, 22, 34, 55, 66]
# sorted() 함수를 사용한 결과: [3, 10, 22, 34, 55, 66]

# %% [markdown]
# <mark>두 개를 모두 메소드(Method)로서 볼 수 있음. sort는 리스트 객체에 속한 메소드이고, sorted는 내장 함수</mark>

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제3]<br><br></span>
# 리스트 x가 있을 때 x.append(7)과 결과가 동일한 것을 모두 골라주세요
#
#
# 1. x[-1:] = [40]
# 2. x.insert(len(x), 40)
# 3. x[0:] = 40
# 4. x[len(x):] = 40
# 5. x[len(x):] = [40]

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 리스트 x에 7을 추가하는 것과 결과가 동일한 옵션
#
# x.insert(len(x), 40)
# x[len(x):] = [40]
#
# 이들 모두 리스트의 마지막에 40을 추가하는 방법.
# (리스트의 마지막에 값을 추가하는 방법)

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제4]<br><br></span>
# 리스트의 모든 요소를 삭제하는 메서드를 골라주세요
#
# 1. remove
# 2. clean
# 3. pop
# 4. clear
# 5. reverse

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 4번

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제5]<br><br></span>
# [3.1, 6.7, 4.4]가 들어있는 리스트의 값을 문자열로 변환 후 다시 리스트로 만들어 변수 x에 담는 코드를 골라주세요
#
# 1. x = list(str, [3.1, 6.7, 4.4])
# 2. x = map(str, [3.1, 6.7, 4.4])
# 3. x = str([3.1, 6.7, 4.4])
# 4. x = list(map(srt, [3.1, 6.7, 4.4]))
# 5. x = map(int, [3.1, 6.7, 4.4])

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 리스트의 값을 문자열(str)로 변환 후 다시 리스트로 만드는 코드
#
# x = list(map(str, [3.1, 6.7, 4.4]))
#
# map() 함수를 사용하여 주어진 리스트의 각 요소를 문자열로 변환, list() 함수를 사용하여 다시 리스트로 만듬.
