# %% [markdown]
# <span style="font-size:100%">
#
# 수업은 모두 열심히 들으셨나요?
#
# 간혹 강의에서 언급되지 않은 내용이 문제로 나올 수 있습니다.<br>
# 그럴땐 강의 내용 외 문제는 구글링을 통해 해결해주세요<br></span>
# <span style="font-size:80%">
# (구글링 또한 개발자가 갖쳐야할 역량 중에 하나랍니다 😊)
# </span>
#
# ---

# %% [markdown]
# <span style="font-size:80%">[문제1]<br><br></span>
# ```주로 작성 중인 코드의 끝을 알리는 기호로 사용되며 파이썬에서 한 줄에 작성된 서로 다른 코드를 구분 지을 때 사용할 수 있는 기호를 골라주세요```
#
# 1. ' , ' (쉼표)
# 2. ' + ' (더하기 기호)
# 3. ' ; ' (세미콜론)
# 4. ' / ' (슬래시)

# %% [markdown]
# <span style="color:red">답변</span> :

# %% [markdown]
# 3번 세미콜론입니다.

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제2]<br><br></span>
# ```Python의 PEP 8은 무엇인지 설명하고 PEP 8의 핵심적인 규칙을 1개 이상을 설명해주세요```

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# PEP 8은 Python 코드 스타일 가이드라인입니다. 코드의 가독성과 일관성을 유지하기 위해 Python 커뮤니티에서 권장하는 스타일을 정의합니다. PEP 8을 따르면 코드를 읽고 이해하기 쉬워지고 다른 개발자들과 협업하기에도 용이합니다.
#
# PEP 8에는 다양한 규칙이 있지만, 그 중 핵심적인 규칙 몇 가지입니다.
#
# 1. 들여쓰기는 4개의 공백을 사용해야 합니다.
# 2. 케이스 스타일, 여러 단어로 구성된 이름은 _ (언더스코어)를 사용하여 연결해야 합니다.
#
# 파이썬에서는 snake 표기법을 주로 사용하고, 자바에서는 camel 표기법을 사용한다고 알고 있습니다.

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제3]<br><br></span>
# ```Python에서 "#"이 의마하는 것은 무엇인지 설명해주세요```

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 주석처리를 하는 것입니다.

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제4]<br><br></span>
# ```Python의 들여쓰기 장점과 기능에 대해 설명해주세요```

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 들여쓰기를 사용하면 코드 블록의 시작과 끝이 명시적으로 표시되므로 중괄호를 사용하는 언어에서 발생하는 오류 중 일부를 방지할 수 있습니다.

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제5]<br><br></span>
# ```print( )문의 기능 및 특징에 대해 설명해주세요```

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# print() 함수는 파이썬 내장함수 중 하나로 특별히 다른 모듈을 활용하지 않아도 사용할 수 있는 함수입니다.
# print는 자료형의 개수의 제한 없이 출력할 수 있고, print에는 직접 출력하고자 하는 값이 있어도 되고, 변수가 있다면 변수의 값을 출력하는 것을 확인할 수 있습니다.
# 하지만 print 함수는 모든 자료형에 대하여 그대로의 출력을 지원하지는 않습니다.
# print 함수 내부적으로 str()를 호출하여 string 형태로 변환한 이후 일괄적으로 문자열 처리를 하기에,
# 만약 자료형이 str() 및.__str__를 지원하지 않는다면 의도한 출력을 얻지 못할 수 있습니다.
