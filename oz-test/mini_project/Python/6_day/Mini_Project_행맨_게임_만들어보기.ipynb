# %% [markdown]
# ## Mini project [행맨 게임 제작]
#
# 안녕하세요.
# 수강생 여러분~! Chapter17 ~ 20 수업은 잘 들으셨나요?
#
# 여러분의 모든 역량을 총 동원해 문제를 풀어주셨합니다.
#
#
#
# #### 과제 설명
#
# 이번 개발 주제는 '행맨' 게임이구요.
#
# 행맨 게임은 아주 유명한 단어 퀴즈 프로그램이예요
#
# 어떤 단어가 주어지면 그 단어의 길이만큼 빈 칸(밑줄) 이 주어지고
# 플레이어는 알파벳을 하나씩 얘기하면서 단어를 추측해요!
#
# 10번만에 맞히지 못하면 게임이 끝납니다. 🥲

# %% [markdown]
# #### 예시를 들어볼께요!!
#
# 만약 E 가 단어에 포함돼있다면, 해당하는 위치에 E 를 표시해줍니다
#
# _ _ _ _ E E
# 이렇게 되겠네요.
#
# 이번에는 A를 해볼께요
# A 는 포함되지 않으므로 기회가 줄어들고 지금까지 맞힌 내용 그대로 출력합니다.
#
# _ _ _ _ E E
# 변화가 없지요.
#
# 이번에는 C 를 해봅시다.
#
# 그럼
# C _ _ _ E E
#
# 다음에는 F 를
# C _ F F E E
#
# 마지막으로 O 를 해보면
# C O F F E E 로 게임은 성공으로 끝나게 됩니다.

# %% [markdown]
# ##본격적인 행맨 게임 규칙 설명
#
# - words 리스트에 추가된 단어들을 사용해주세요
#   - words = ["apple", "banana", "orange", "grape", "lemon"]
#
# - 단어의 길이에 맞게 밑줄을 출력해주세요
#   (예)banana의 경우 _ _ _ _ _ _
#
# - 사용자부터 1글자씩 입력을 받되,
#    - 단어에 입력값이 포함되면 "단어를 맞추셨군요. 더 힘내봐요"라고 출력해주세요"
#    - 단어에 입력값이 포함되어 있지 않다면 "틀렸습니다. 남은 시도 횟수 "란 메시지와 함꼐 남은 횟수를 출력해주세요
#
# - 매번 입력을 받을 때마다 현재까지 맞힌 글자들 표시(맞히면 글자는 밑줄 출력)
#     - 예) a 입력 시 : a _ _ _ _
#           p 입력 시 : a p p _ _
#           c 입력 시 : a p p _ _
#
# - 모든 단어를 맞췄을 경우 "축하합니다! 단어를 맞추셨습니다"와 시도 횟수를 출력해주세요
#
#
# 행맨은 정말 유명 게임으로 찾아볼 수 있는 자료들이 많습니다.
# 문제가 어려우신 경우 구글링 통해 문제를 해결해보세요.

# %%
import random

# 단어 리스트 정의
words = ["apple", "banana", "orange", "grape", "lemon"]

# 현재까지 맞힌 글자들을 보여주는 함수
def display_word(word, guessed_letters):
    result = ""
    for letter in word:
        if letter in guessed_letters:
            result += letter + " "  # 맞힌 글자는 표시
        else:
            result += "_ "  # 틀린 경우에는 밑줄로 표시
    return result.strip()

# 행맨 게임 실행하는 함수
def hangman():
    attempts = 6  # 허용되는 시도 횟수 초기화
    word = random.choice(words)  # 랜덤한 단어 선택
    guessed_letters = []
    print("행맨 게임에 오신 것을 환영합니다!")
    print("이 단어는", len(word), "글자입니다.")  # 선택된 단어의 길이 출력
    print(display_word(word, guessed_letters))  # 현재까지 맞힌 글자들 표시

    while attempts > 0:
        guess = input("\n한 글자를 입력해주세요: ").lower()  # 사용자 입력 받음
        if guess in word:
            print("성공!")  # 맞힌 경우
            guessed_letters.append(guess)  # 맞힌 글자 추가
            print(display_word(word, guessed_letters))  # 현재까지 맞힌 글자들 표시
        else:
            attempts -= 1  # 틀린 경우 시도 횟수 감소
            print("실패! 남은 시도 횟수는", attempts, "번입니다.")  # 남은 시도 횟수 출력
            print(display_word(word, guessed_letters))  # 현재까지 맞힌 글자들 표시

        if "_" not in display_word(word, guessed_letters):
            print("축하합니다! 단어를 맞추셨습니다:", word)  # 모든 단어를 맞힌 경우
            break
    else:
        print("게임 종료! 정답은:", word)  # 모든 시도 횟수를 소진한 경우

if __name__ == "__main__":
    hangman()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 42
#      39         print("게임 종료! 정답은:", word)  # 모든 시도 횟수를 소진한 경우
#      41 if __name__ == "__main__":
# ---> 42     hangman()
#
# Cell In[11], line 19, in hangman()
#      17 def hangman():
#      18     attempts = 6  # 허용되는 시도 횟수 초기화
# ---> 19     word = random.choice(words)  # 랜덤한 단어 선택
#      20     guessed_letters = []
#      21     print("행맨 게임에 오신 것을 환영합니다!")
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'choice'
